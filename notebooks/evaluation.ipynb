# %% [markdown]
# # Model Evaluation & Validation

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path("..").resolve()
sys.path.append(str(PROJECT_ROOT))

from src.evaluate import run_evaluation

run_evaluation()
# Out:
# Loading latest model: model_20260319_103124.pkl
# Model loaded successfully.
# Loading latest file: split_data_20260319_103124.pkl
# Successfully loaded: split_data_20260319_103124.pkl
# 2026-03-19 10:57:58,668 - INFO - Evaluation Metrics: {'MSE': 11685.64, 'RMSE': 108.1, 'R2': 0.9992148573854697}
#                    MSE   RMSE        R2
# XGBRegressor  11685.64  108.1  0.999215
