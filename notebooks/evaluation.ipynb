# %% [markdown]
# # Model Evaluation & Validation

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path("..").resolve()
sys.path.append(str(PROJECT_ROOT))

from src.evaluate import run_evaluation

run_evaluation()
# Out:
# Loading latest model: model_20260204_152833.pkl
# Model loaded successfully.
# Loading latest file: split_data_20260204_152833.pkl
# Successfully loaded: split_data_20260204_152833.pkl
# 2026-02-04 16:03:37,091 - INFO - Evaluation Metrics: {'MSE': 24464.85, 'RMSE': 156.41, 'R2': 0.9983562392924906}
#                    MSE    RMSE        R2
# XGBRegressor  24464.85  156.41  0.998356
