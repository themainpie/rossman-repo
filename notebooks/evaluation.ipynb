# %% [markdown]
# # Model Evaluation & Validation

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path("..").resolve()
sys.path.append(str(PROJECT_ROOT))

from src.evaluate import run_evaluation

run_evaluation()
# Out:
# Loading latest model: model_20260304_154022.pkl
# Model loaded successfully.
# Loading latest file: split_data_20260304_154022.pkl
# Successfully loaded: split_data_20260304_154022.pkl
# 2026-03-04 15:47:27,320 - INFO - Evaluation Metrics: {'MSE': 13226.71, 'RMSE': 115.01, 'R2': 0.9991113151973221}
#                    MSE    RMSE        R2
# XGBRegressor  13226.71  115.01  0.999111
