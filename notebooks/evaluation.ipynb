# %% [markdown]
# # Model Evaluation & Validation

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path("..").resolve()
sys.path.append(str(PROJECT_ROOT))

from src.evaluate import run_evaluation

run_evaluation()
# Out:
# Loading latest model: model_20260311_181902.pkl
# Model loaded successfully.
# Loading latest file: split_data_20260311_181902.pkl
# Successfully loaded: split_data_20260311_181902.pkl
# 2026-03-12 13:36:28,123 - INFO - Evaluation Metrics: {'MSE': 13622.83, 'RMSE': 116.72, 'R2': 0.9990847000321251}
#                    MSE    RMSE        R2
# XGBRegressor  13622.83  116.72  0.999085
