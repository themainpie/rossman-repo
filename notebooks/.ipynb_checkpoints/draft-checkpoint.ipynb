# %%
import yaml
import sys
from pathlib import Path

PROJECT_ROOT = Path("..").resolve()
sys.path.append(str(PROJECT_ROOT))

config_path = PROJECT_ROOT / "config.yaml"
with open(config_path) as f:
    config = yaml.safe_load(f)

from src.load_data import load_train, load_test, load_store, load_processed_data
from src.preprocess import merge_store_data, clean_data, prepare_data, add_features, build_preprocessing_pipeline
from src.train import time_split, demo_train, train

# %%
train_data = load_train()
store = load_store()
# Out:
# C:\Users\mrdow\rossman\src\load_data.py:16: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   train = pd.read_csv(RAW_DATA_DIR / "train.csv")

# %%
X_train, y_train, X_test, y_test, X_grp, y_grp = load_processed_data()
# Out:
# Loading latest file: split_data_20260126_174225.pkl
# Successfully loaded: split_data_20260126_174225.pkl

# %%
X_train
# Out:
#          Store  DayOfWeek  Customers  Open  Promo StateHoliday  SchoolHoliday  \
# 210735       1          5        489     1      0            0              0
# 210736       2          5        418     1      0            0              0
# 210737       3          5        672     1      0            0              0
# 210738       4          5       1129     1      0            0              0
# 210739       5          5        476     1      0            0              0
# ...        ...        ...        ...   ...    ...          ...            ...
# 1017204   1111          2          0     0      0            a              1
# 1017205   1112          2          0     0      0            a              1
# 1017206   1113          2          0     0      0            a              1
# 1017207   1114          2          0     0      0            a              1
# 1017208   1115          2          0     0      0            a              1
#
# ...

# %%
train_data
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday
# 0                  0              1
# 1                  0              1
# ...

# %%
X, y = prepare_data(train_data, store, config, "Sales")
groups = X.pop("Date")

# %%
X_train, X_test, y_train, y_test, groups_train, groups_test = time_split(X, y, groups)

X_train
# Out:
#          Store  DayOfWeek  Customers  Open  Promo StateHoliday  SchoolHoliday  \
# 210735       1          5        489     1      0            0              0
# 210736       2          5        418     1      0            0              0
# 210737       3          5        672     1      0            0              0
# 210738       4          5       1129     1      0            0              0
# 210739       5          5        476     1      0            0              0
# ...        ...        ...        ...   ...    ...          ...            ...
# 1017204   1111          2          0     0      0            a              1
# 1017205   1112          2          0     0      0            a              1
# 1017206   1113          2          0     0      0            a              1
# 1017207   1114          2          0     0      0            a              1
# 1017208   1115          2          0     0      0            a              1
#
# ...

# %%
train()
# Out:
# C:\Users\mrdow\rossman\src\load_data.py:8: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   train = pd.read_csv(base_path / "train.csv")
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# training finished
# np.float64(0.9973392089207967)
